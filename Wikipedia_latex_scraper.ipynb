# %%
import requests
from bs4 import BeautifulSoup
import re
from sympy import preview 
import pandas as pd
import os

# %%
# Step 1: Fetch the Mathematics Portal Page
url = "https://en.wikipedia.org/wiki/Portal:Mathematics"
response = requests.get(url)

# Step 2: Parse the HTML Content
soup = BeautifulSoup(response.content, 'html.parser')

# Step 3: Extract Links
links = soup.find_all("a")

# Step 4: Filter and Validate Links
valid_links = []
for link in links:
    href = link.get("href", "")
    # Check if the link is a valid Wikipedia link related to mathematics
    if re.match(r'^/wiki/', href) and not re.search(r'/\w+:', href):
        valid_links.append(href)

https_links = [f"https://en.wikipedia.org{link}" for link in valid_links]

# %%
len(https_links)
# Out:
# 703

# %%
def parse_for_equations(url):
    page = url.split("/")[-1]
    # Fetch the HTML content of a Wikipedia page
    response = requests.get(url)
    html_content = response.content
    
    # Regular expression pattern to match the "displaystyle" block
    pattern = r'{\\displaystyle .*?}'
    
    # Parse the HTML using BeautifulSoup
    soup = BeautifulSoup(html_content, "html.parser")
    
    # Find all LaTeX equations and their corresponding images
    equation_strings = []
    latex_equations = soup.find_all("math")
    for i, equation in enumerate(latex_equations):
        latex_text = equation.text
        
        match = re.search(pattern, latex_text)
        if match:
            cleaned_equation = latex_text[match.start():-2]
            try:
                preview(f"$${cleaned_equation}$$", viewer='file', filename=f'latex_images/{page}_{i}.png', euler=False)
                equation_strings.append({"name": f"{page}_{i}", "latex": cleaned_equation})
            except RuntimeError as e:
                print(f"Equation {repr(cleaned_equation)} failed to render")
    
    df = pd.DataFrame(data=equation_strings)
    df.to_csv(f'latex_strings/{page}.csv', index=False)

# %%
for url in https_links:
    page = url.split("/")[-1]
    existing_pages = [s[:-4] for s in os.listdir("latex_strings")]
    if page not in existing_pages:
        print(url)
        parse_for_equations(url)
# Out:
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Euler%27s_Identity
# https://en.wikipedia.org/wiki/Mathematics
# https://en.wikipedia.org/wiki/Mathematical_notation
# https://en.wikipedia.org/wiki/Mathematical_proof
# https://en.wikipedia.org/wiki/Mathematical_object
# https://en.wikipedia.org/wiki/Number
# Equation '{\\displaystyle {\\text{∞}}}' failed to render
# https://en.wikipedia.org/wiki/Point_(geometry)
# https://en.wikipedia.org/wiki/Euclidean_space
# Equation '{\\displaystyle {\\begin{aligned}|BC|^{2}&={\\overrightarrow {BC}}\\cdot {\\overrightarrow {BC}}{\\vphantom {\\frac {(}{}}}\\\\u]&={\\Bigl (}{\\overrightarrow {BA}}+{\\overrightarrow {AC}}{\\Bigr )}\\cdot {\\Bigl (}{\\overrightarrow {BA}}+{\\overrightarrow {AC}}{\\Bigr )}\\\\u]&={\\overrightarrow {BA}}\\cdot {\\overrightarrow {BA}}+{\\overrightarrow {AC}}\\cdot {\\overrightarrow {AC}}-2{\\overrightarrow {AB}}\\cdot {\\overrightarrow {AC}}\\\\u]&={\\overrightarrow {AB}}\\cdot {\\overrightarrow {AB}}+{\\overrightarrow {AC}}\\cdot {\\overrightarrow {AC}}\\\\u]&=|AB|^{2}+|AC|^{2}.\\end{aligned}}}' failed to render
# https://en.wikipedia.org/wiki/Set_(mathematics)
# https://en.wikipedia.org/wiki/Mathematical_structure
# https://en.wikipedia.org/wiki/Game_Theory
# https://en.wikipedia.org/wiki/Natural_science
# https://en.wikipedia.org/wiki/Engineering
# https://en.wikipedia.org/wiki/Medicine
# https://en.wikipedia.org/wiki/Social_sciences
# https://en.wikipedia.org/wiki/Applied_mathematics
# https://en.wikipedia.org/wiki/Statistics
# https://en.wikipedia.org/wiki/Game_theory
# https://en.wikipedia.org/wiki/Pure_mathematics
# https://en.wikipedia.org/wiki/Balance_scale
# https://en.wikipedia.org/wiki/0_(number)
# https://en.wikipedia.org/wiki/Even_number
# https://en.wikipedia.org/wiki/Parity_(mathematics)
# https://en.wikipedia.org/wiki/Integer
# https://en.wikipedia.org/wiki/Multiple_(mathematics)
# https://en.wikipedia.org/wiki/2_(number)
# Equation '{\\displaystyle \\{\\{\\varnothing \\},\\varnothing \\}}' failed to render
# Equation '{\\displaystyle \\varnothing }' failed to render
# https://en.wikipedia.org/wiki/Identity_element
# https://en.wikipedia.org/wiki/Group_(mathematics)
# Equation '{\\displaystyle \\mathbb {R} \\smallsetminus \\{0\\}}' failed to render
# Equation '{\\displaystyle \\mathbb {Q} \\smallsetminus \\left\\{0\\right\\}=\\left\\{q\\in \\mathbb {Q} \\mid q\\neq 0\\right\\}}' failed to render
# Equation '{\\displaystyle \\left(\\mathbb {Q} \\smallsetminus \\left\\{0\\right\\},\\cdot \\right)}' failed to render
# Equation '{\\displaystyle (\\mathbb {Z} \\smallsetminus \\{0\\},\\cdot )}' failed to render
# Equation '{\\displaystyle (\\mathbb {Z} \\smallsetminus \\{0\\},\\cdot )}' failed to render
# Equation '{\\displaystyle (\\mathbb {Q} \\smallsetminus \\{0\\},\\cdot )}' failed to render
# https://en.wikipedia.org/wiki/Natural_number
# Equation '{\\displaystyle \\{1,2,...\\}=\\mathbb {N} ^{*}=\\mathbb {N} ^{+}=\\mathbb {N} _{0}\\smallsetminus \\{0\\}=\\mathbb {N} _{1}}' failed to render
# https://en.wikipedia.org/wiki/Recursive_definition
# https://en.wikipedia.org/wiki/Graph_theory
# https://en.wikipedia.org/wiki/Computational_geometry
# https://en.wikipedia.org/wiki/Power_of_2
# https://en.wikipedia.org/wiki/Binary_numeral_system
# https://en.wikipedia.org/wiki/Parity_of_zero
# https://en.wikipedia.org/wiki/Classical_mechanics
# https://en.wikipedia.org/wiki/Laplace%E2%80%93Runge%E2%80%93Lenz_vector
# https://en.wikipedia.org/wiki/Vector_(geometric)
# https://en.wikipedia.org/wiki/Orbit_(celestial_mechanics)
# https://en.wikipedia.org/wiki/Binary_star
# https://en.wikipedia.org/wiki/Two-body_problem
# https://en.wikipedia.org/wiki/Newton%27s_law_of_universal_gravitation
# https://en.wikipedia.org/wiki/Constant_of_motion
# https://en.wikipedia.org/wiki/Conservation_law
# https://en.wikipedia.org/wiki/Central_force
# https://en.wikipedia.org/wiki/Inverse_square_law
# https://en.wikipedia.org/wiki/Kepler_problem
# https://en.wikipedia.org/wiki/Hydrogen_atom
# https://en.wikipedia.org/wiki/Coulomb%27s_law
# https://en.wikipedia.org/wiki/Electrostatics
# https://en.wikipedia.org/wiki/Quantum_mechanic
# https://en.wikipedia.org/wiki/Atomic_emission_spectrum
# https://en.wikipedia.org/wiki/Schr%C3%B6dinger_equation
# https://en.wikipedia.org/wiki/Richard_Feynman
# https://en.wikipedia.org/wiki/Theoretical_physicist
# https://en.wikipedia.org/wiki/Path_integral_formulation
# https://en.wikipedia.org/wiki/Quantum_mechanics
# https://en.wikipedia.org/wiki/Quantum_electrodynamics
# https://en.wikipedia.org/wiki/Superfluidity
# https://en.wikipedia.org/wiki/Liquid_helium
# https://en.wikipedia.org/wiki/Particle_physics
# https://en.wikipedia.org/wiki/Parton_model
# https://en.wikipedia.org/wiki/Nobel_Prize_in_Physics
# https://en.wikipedia.org/wiki/Julian_Schwinger
# https://en.wikipedia.org/wiki/Shin%27ichir%C5%8D_Tomonaga
# https://en.wikipedia.org/wiki/Subatomic_particle
# https://en.wikipedia.org/wiki/Feynman_diagram
# https://en.wikipedia.org/wiki/Physics_World
# https://en.wikipedia.org/wiki/Jakob_Emanuel_Handmann
# https://en.wikipedia.org/wiki/Leonhard_Euler
# https://en.wikipedia.org/wiki/Old_Swiss_Confederacy
# https://en.wikipedia.org/wiki/Mathematician
# https://en.wikipedia.org/wiki/Physicist
# https://en.wikipedia.org/wiki/Astronomer
# https://en.wikipedia.org/wiki/Geographer
# https://en.wikipedia.org/wiki/Logician
# https://en.wikipedia.org/wiki/Topology
# https://en.wikipedia.org/wiki/Analytic_number_theory
# https://en.wikipedia.org/wiki/Complex_analysis
# https://en.wikipedia.org/wiki/Infinitesimal_calculus
# https://en.wikipedia.org/wiki/Mathematical_function
# Equation '{\\displaystyle \\varnothing \\to X}' failed to render
# Equation '{\\displaystyle \\varnothing \\to Y}' failed to render
# https://en.wikipedia.org/wiki/Mechanics
# https://en.wikipedia.org/wiki/Fluid_dynamics
# https://en.wikipedia.org/wiki/Optics
# https://en.wikipedia.org/wiki/Astronomy
# https://en.wikipedia.org/wiki/Music_theory
# https://en.wikipedia.org/wiki/Pierre-Simon_Laplace
# https://en.wikipedia.org/wiki/Carl_Friedrich_Gauss
# https://en.wikipedia.org/wiki/Opera_Omnia_Leonhard_Euler
# https://en.wikipedia.org/wiki/Quarto
# https://en.wikipedia.org/wiki/Saint_Petersburg
# https://en.wikipedia.org/wiki/Berlin
# https://en.wikipedia.org/wiki/Kingdom_of_Prussia
# https://en.wikipedia.org/wiki/1_%E2%88%92_2_%2B_3_%E2%88%92_4_%2B_%E2%8B%AF
# https://en.wikipedia.org/wiki/Series_(mathematics)
# https://en.wikipedia.org/wiki/Positive_integer
# Equation '{\\displaystyle \\{1,2,...\\}=\\mathbb {N} ^{*}=\\mathbb {N} ^{+}=\\mathbb {N} _{0}\\smallsetminus \\{0\\}=\\mathbb {N} _{1}}' failed to render
# https://en.wikipedia.org/wiki/Alternating_series
# https://en.wikipedia.org/wiki/Summation
# Equation '{\\displaystyle b\\geqslant a}' failed to render
# Equation '{\\displaystyle \\sum _{i=0}^{n}{\\frac {n \\choose i}{i+1}}={\\frac {2^{n+1}-1}{n+1}},}' failed to render
# https://en.wikipedia.org/wiki/Divergent_series
# https://en.wikipedia.org/wiki/Partial_sum
# https://en.wikipedia.org/wiki/Limit_of_a_sequence
# Equation '{\\displaystyle x_{n,m}\\rightrightarrows y_{m}}' failed to render
# https://en.wikipedia.org/wiki/List_of_paradoxes#Mathematics
# https://en.wikipedia.org/wiki/Pi
# https://en.wikipedia.org/wiki/Mathematical_constant
# Equation '{\\displaystyle C_{10}=0.{\\color {blue}{1}}2{\\color {blue}{3}}4{\\color {blue}{5}}6{\\color {blue}{7}}8{\\color {blue}{9}}10{\\color {blue}{11}}12{\\color {blue}{13}}14{\\color {blue}{15}}16\\dots }' failed to render
# https://en.wikipedia.org/wiki/Ratio
# https://en.wikipedia.org/wiki/Circle
# Equation '{\\displaystyle {\\frac {({\\color {green}x}-x_{1})({\\color {green}x}-x_{2})+({\\color {red}y}-y_{1})({\\color {red}y}-y_{2})}{({\\color {red}y}-y_{1})({\\color {green}x}-x_{2})-({\\color {red}y}-y_{2})({\\color {green}x}-x_{1})}}={\\frac {(x_{3}-x_{1})(x_{3}-x_{2})+(y_{3}-y_{1})(y_{3}-y_{2})}{(y_{3}-y_{1})(x_{3}-x_{2})-(y_{3}-y_{2})(x_{3}-x_{1})}}.}' failed to render
# https://en.wikipedia.org/wiki/Circumference
# https://en.wikipedia.org/wiki/Diameter
# Equation '{\\displaystyle \\varnothing .}' failed to render
# Equation '{\\displaystyle S=\\varnothing }' failed to render
# https://en.wikipedia.org/wiki/Physics
# https://en.wikipedia.org/wiki/Irrational_number
# https://en.wikipedia.org/wiki/Approximations_of_%CF%80
# Equation '{\\displaystyle {\\begin{aligned}\\arctan x&={\\frac {x}{1+x^{2}}}\\sum _{k=0}^{\\infty }{\\frac {(2k)!!\\,x^{2k}}{(2k+1)!!\\,(1+x^{2})^{k}}}={\\frac {x}{1+x^{2}}}+{\\frac {2}{3}}{\\frac {x^{3}}{(1+x^{2})^{2}}}+{\\frac {2\\cdot 4}{3\\cdot 5}}{\\frac {x^{5}}{(1+x^{2})^{3}}}+\\cdots \\\\u]{\\frac {\\pi }{2}}&=\\sum _{k=0}^{\\infty }{\\frac {k!}{(2k+1)!!}}=\\sum _{k=0}^{\\infty }{\\cfrac {2^{k}k!^{2}}{(2k+1)!}}=1+{\\frac {1}{3}}\\left(1+{\\frac {2}{5}}\\left(1+{\\frac {3}{7}}\\left(1+\\cdots \\right)\\right)\\right)\\end{aligned}}}' failed to render
# https://en.wikipedia.org/wiki/Decimal_representation
# https://en.wikipedia.org/wiki/Repeating_decimal
# Equation '{\\displaystyle {\\begin{array}{lllll}3.254444\\ldots &=3.25{\\overline {4}}&={\\begin{Bmatrix}\\mathbf {I} =3&\\mathbf {A} =25&\\mathbf {P} =4\\\\&\\#\\mathbf {A} =2&\\#\\mathbf {P} =1\\end{Bmatrix}}&={\\dfrac {3254-325}{900}}&={\\dfrac {2929}{900}}\\\\\\\\0.512512\\ldots &=0.{\\overline {512}}&={\\begin{Bmatrix}\\mathbf {I} =0&\\mathbf {A} =\\emptyset &\\mathbf {P} =512\\\\&\\#\\mathbf {A} =0&\\#\\mathbf {P} =3\\end{Bmatrix}}&={\\dfrac {512-0}{999}}&={\\dfrac {512}{999}}\\\\\\\\1.09191\\ldots &=1.0{\\overline {91}}&={\\begin{Bmatrix}\\mathbf {I} =1&\\mathbf {A} =0&\\mathbf {P} =91\\\\&\\#\\mathbf {A} =1&\\#\\mathbf {P} =2\\end{Bmatrix}}&={\\dfrac {1091-10}{990}}&={\\dfrac {1081}{990}}\\\\\\\\1.333\\ldots &=1.{\\overline {3}}&={\\begin{Bmatrix}\\mathbf {I} =1&\\mathbf {A} =\\emptyset &\\mathbf {P} =3\\\\&\\#\\mathbf {A} =0&\\#\\mathbf {P} =1\\end{Bmatrix}}&={\\dfrac {13-1}{9}}&={\\dfrac {12}{9}}&={\\dfrac {4}{3}}\\\\\\\\0.3789789\\ldots &=0.3{\\overline {789}}&={\\begin{Bmatrix}\\mathbf {I} =0&\\mathbf {A} =3&\\mathbf {P} =789\\\\&\\#\\mathbf {A} =1&\\#\\mathbf {P} =3\\end{Bmatrix}}&={\\dfrac {3789-3}{9990}}&={\\dfrac {3786}{9990}}&={\\dfrac {631}{1665}}\\end{array}}}' failed to render
# Equation '{\\displaystyle b\\in \\mathbb {Z} \\smallsetminus \\{-1,0,1\\}}' failed to render
# https://en.wikipedia.org/wiki/Transcendental_number
# Equation '{\\displaystyle 1\\leqslant a\\leqslant n}' failed to render
# https://en.wikipedia.org/wiki/Equation
# https://en.wikipedia.org/wiki/Squaring_the_circle
# Equation '{\\displaystyle |P_{3}P_{9}|=|P_{1}P_{2}|{\\sqrt {{\\frac {40}{3}}-2{\\sqrt {3}}}}\\approx 3.141\\,5{\\color {red}33\\,338}\\cdot |P_{1}P_{2}|\\approx \\pi r.}' failed to render
# Equation '{\\displaystyle \\pi \\approx {\\frac {355}{113}}=3.141\\;592{\\color {red}\\;920\\;\\ldots }}' failed to render
# Equation '{\\displaystyle {\\frac {6}{5}}\\cdot \\left(1+\\varphi \\right)=3.141\\;{\\color {red}640\\;\\ldots },}' failed to render
# Equation '{\\displaystyle \\left(9^{2}+{\\frac {19^{2}}{22}}\\right)^{\\frac {1}{4}}={\\sqrt[{4}]{\\frac {2143}{22}}}=3.141\\;592\\;65{\\color {red}2\\;582\\;\\ldots }}' failed to render
# https://en.wikipedia.org/wiki/Compass-and-straightedge_construction
# Equation '{\\displaystyle {\\begin{aligned}\\cos {\\left({\\frac {2\\pi }{17}}\\right)}&=\\,-{\\frac {1}{16}}\\,+\\,{\\frac {1}{16}}{\\sqrt {17}}\\,+\\,{\\frac {1}{16}}{\\sqrt {34-2{\\sqrt {17}}}}\\\\u]&\\qquad +\\,{\\frac {1}{8}}{\\sqrt {17+3{\\sqrt {17}}-{\\sqrt {34-2{\\sqrt {17}}}}-2{\\sqrt {34+2{\\sqrt {17}}}}}}\\end{aligned}}}' failed to render
# https://en.wikipedia.org/wiki/Random_sequence
# https://en.wikipedia.org/wiki/Egyptian_mathematics
# https://en.wikipedia.org/wiki/Babylonian_mathematics
# https://en.wikipedia.org/wiki/Greek_mathematics
# https://en.wikipedia.org/wiki/Archimedes
# https://en.wikipedia.org/wiki/Chinese_mathematics
# https://en.wikipedia.org/wiki/Indian_mathematics
# https://en.wikipedia.org/wiki/Pi_(letter)
# https://en.wikipedia.org/wiki/William_Jones_(mathematician)
# https://en.wikipedia.org/wiki/Marian_Rejewski
# https://en.wikipedia.org/wiki/Polish_people
# https://en.wikipedia.org/wiki/Cryptography
# https://en.wikipedia.org/wiki/Enigma_machine
# https://en.wikipedia.org/wiki/French_secret_service
# https://en.wikipedia.org/wiki/Jerzy_R%C3%B3%C5%BCycki
# https://en.wikipedia.org/wiki/Henryk_Zygalski
# https://en.wikipedia.org/wiki/Polish_General_Staff
# https://en.wikipedia.org/wiki/Cipher_Bureau_(Poland)
# https://en.wikipedia.org/wiki/Card_catalog_(cryptology)
# https://en.wikipedia.org/wiki/Cryptologic_bomb
# https://en.wikipedia.org/wiki/Georg_Cantor
# https://en.wikipedia.org/wiki/Old_Style_and_New_Style_dates
# https://en.wikipedia.org/wiki/Set_theory
# https://en.wikipedia.org/wiki/Foundations_of_mathematics
# https://en.wikipedia.org/wiki/One-to-one_correspondence
# https://en.wikipedia.org/wiki/Infinite_set
# https://en.wikipedia.org/wiki/Well-order
# Equation '{\\displaystyle S\\neq \\varnothing :}' failed to render
# Equation '{\\displaystyle {\\begin{matrix}0&2&4&6&8&\\dots &1&3&5&7&9&\\dots \\end{matrix}}}' failed to render
# https://en.wikipedia.org/wiki/Real_number
# https://en.wikipedia.org/wiki/Infinity
# Equation '{\\displaystyle \\mathbf {c} =\\aleph _{1}=\\beth _{1}}' failed to render
# https://en.wikipedia.org/wiki/Cardinal_number
# Equation '{\\displaystyle \\kappa ^{+}\\nleq \\kappa .}' failed to render
# https://en.wikipedia.org/wiki/Ordinal_number
# https://en.wikipedia.org/wiki/Transfinite_number
# https://en.wikipedia.org/wiki/Leopold_Kronecker
# https://en.wikipedia.org/wiki/Henri_Poincar%C3%A9
# https://en.wikipedia.org/wiki/Hermann_Weyl
# https://en.wikipedia.org/wiki/L._E._J._Brouwer
# https://en.wikipedia.org/wiki/Ludwig_Wittgenstein
# https://en.wikipedia.org/wiki/Philosophical_objections_to_Cantor%27s_theory
# https://en.wikipedia.org/wiki/Controversy_over_Cantor%27s_theory
# https://en.wikipedia.org/wiki/Lutheran_Christian
# https://en.wikipedia.org/wiki/Christian_theology
# https://en.wikipedia.org/wiki/Neo-Scholasticism
# https://en.wikipedia.org/wiki/Pantheism
# https://en.wikipedia.org/wiki/Johann_Baptist_Franzelin
# https://en.wikipedia.org/wiki/Josiah_Willard_Gibbs
# https://en.wikipedia.org/wiki/Thermodynamics
# https://en.wikipedia.org/wiki/Physical_chemistry
# https://en.wikipedia.org/wiki/James_Clerk_Maxwell
# https://en.wikipedia.org/wiki/Ludwig_Boltzmann
# https://en.wikipedia.org/wiki/Statistical_mechanics
# https://en.wikipedia.org/wiki/Laws_of_thermodynamics
# https://en.wikipedia.org/wiki/Statistical_ensemble_(mathematical_physics)
# https://en.wikipedia.org/wiki/Maxwell%27s_equations
# https://en.wikipedia.org/wiki/Physical_optics
# https://en.wikipedia.org/wiki/Vector_calculus
# https://en.wikipedia.org/wiki/Oliver_Heaviside
# https://en.wikipedia.org/wiki/Yale_University
# https://en.wikipedia.org/wiki/Doctor_of_Philosophy
# https://en.wikipedia.org/wiki/Mathematical_physics
# https://en.wikipedia.org/wiki/Albert_Einstein
# https://en.wikipedia.org/wiki/Copley_Medal
# https://en.wikipedia.org/wiki/Royal_Society
# https://en.wikipedia.org/wiki/Ted_Kaczynski
# https://en.wikipedia.org/wiki/Domestic_terrorism_in_the_United_States
# https://en.wikipedia.org/wiki/Child_prodigy
# https://en.wikipedia.org/wiki/Simple_living
# https://en.wikipedia.org/wiki/Mail_bomb
# https://en.wikipedia.org/wiki/Natural_environment
# https://en.wikipedia.org/wiki/Industrial_Society_and_Its_Future
# https://en.wikipedia.org/wiki/Manifesto
# https://en.wikipedia.org/wiki/Social_critique
# https://en.wikipedia.org/wiki/Leftism
# https://en.wikipedia.org/wiki/Anarchism
# https://en.wikipedia.org/wiki/Cassini-Huygens
# https://en.wikipedia.org/wiki/Shapiro_effect
# https://en.wikipedia.org/wiki/Spacetime
# https://en.wikipedia.org/wiki/Sun
# https://en.wikipedia.org/wiki/Introduction_to_general_relativity
# https://en.wikipedia.org/wiki/Scientific_theory
# https://en.wikipedia.org/wiki/Gravitation
# https://en.wikipedia.org/wiki/Emmy_Noether
# https://en.wikipedia.org/wiki/American_English
# https://en.wikipedia.org/wiki/British_English
# https://en.wikipedia.org/wiki/Abstract_algebra
# https://en.wikipedia.org/wiki/Noether%27s_theorem
# https://en.wikipedia.org/wiki/Noether%27s_second_theorem
# https://en.wikipedia.org/wiki/Pavel_Alexandrov
# https://en.wikipedia.org/wiki/Jean_Dieudonn%C3%A9
# https://en.wikipedia.org/wiki/Norbert_Wiener
# https://en.wikipedia.org/wiki/List_of_women_in_mathematics
# https://en.wikipedia.org/wiki/Ring_(mathematics)
# https://en.wikipedia.org/wiki/Field_(mathematics)
# Equation '{\\displaystyle (F\\smallsetminus \\{0\\},\\cdot )}' failed to render
# Equation '{\\displaystyle F\\smallsetminus \\{0\\}}' failed to render
# Equation '{\\displaystyle F\\smallsetminus \\{0\\}}' failed to render
# Equation '{\\displaystyle K_{n}^{M}(F)=F^{\\times }\\otimes \\cdots \\otimes F^{\\times }/\\left\\langle x\\otimes (1-x)\\mid x\\in F\\smallsetminus \\{0,1\\}\\right\\rangle .}' failed to render
# Equation '{\\displaystyle \\left\\langle F\\smallsetminus \\{0\\},\\cdot ,{}^{-1}\\right\\rangle }' failed to render
# https://en.wikipedia.org/wiki/Algebra_over_a_field
# https://en.wikipedia.org/wiki/Symmetry_in_physics
# https://en.wikipedia.org/wiki/Conservation_law_(physics)
# https://en.wikipedia.org/wiki/Jewish_family
# https://en.wikipedia.org/wiki/Franconia
# https://en.wikipedia.org/wiki/Erlangen
# https://en.wikipedia.org/wiki/Max_Noether
# https://en.wikipedia.org/wiki/University_of_Erlangen
# https://en.wikipedia.org/wiki/Paul_Gordan
# https://en.wikipedia.org/wiki/David_Hilbert
# https://en.wikipedia.org/wiki/Felix_Klein
# https://en.wikipedia.org/wiki/University_of_G%C3%B6ttingen
# https://en.wikipedia.org/wiki/Habilitation
# https://en.wikipedia.org/wiki/Privatdozent
# https://en.wikipedia.org/wiki/Logarithm
# https://en.wikipedia.org/wiki/Inverse_function
# Equation '{\\displaystyle f\\colon \\varnothing \\to \\varnothing }' failed to render
# https://en.wikipedia.org/wiki/Exponentiation
# https://en.wikipedia.org/wiki/Exponent
# https://en.wikipedia.org/wiki/Big_O_notation
# Equation '{\\displaystyle {\\color {red}f(x)}=O{\\color {blue}(g(x))}}' failed to render
# Equation '{\\displaystyle 0\\leq {\\color {red}f(x)}\\leq M{\\color {blue}g(x)}}' failed to render
# Equation '{\\displaystyle f\\preccurlyeq g\\iff f=O(g)}' failed to render
# Equation '{\\displaystyle \\preccurlyeq }' failed to render
# Equation '{\\displaystyle \\preccurlyeq }' failed to render
# https://en.wikipedia.org/wiki/Common_logarithm
# https://en.wikipedia.org/wiki/Natural_logarithm
# https://en.wikipedia.org/wiki/E_(mathematical_constant)
# https://en.wikipedia.org/wiki/Derivative
# https://en.wikipedia.org/wiki/Binary_logarithm
# https://en.wikipedia.org/wiki/Computer_science
# https://en.wikipedia.org/wiki/Rubik%27s_Cube
# https://en.wikipedia.org/wiki/Rubik%27s_Cube_group
# Equation '{\\displaystyle G=C_{o}\\rtimes C_{p}.\\,}' failed to render
# Equation '{\\displaystyle C_{p}=(A_{8}\\times A_{12})\\,\\rtimes \\mathbb {Z} _{2}.}' failed to render
# Equation '{\\displaystyle (\\mathbb {Z} _{3}^{7}\\times \\mathbb {Z} _{2}^{11})\\rtimes \\,((A_{8}\\times A_{12})\\rtimes \\mathbb {Z} _{2}).}' failed to render
# Equation '{\\displaystyle [(\\mathbb {Z} _{3}^{7}\\rtimes \\mathrm {S} _{8})\\times (\\mathbb {Z} _{2}^{11}\\rtimes \\mathrm {S} _{12})]^{\\frac {1}{2}}}' failed to render
# Equation '{\\displaystyle [\\mathbb {Z} _{4}^{6}\\times (\\mathbb {Z} _{3}^{7}\\rtimes \\mathrm {S} _{8})\\times (\\mathbb {Z} _{2}^{11}\\rtimes \\mathrm {S} _{12})]^{\\frac {1}{2}}.}' failed to render
# https://en.wikipedia.org/wiki/Binary_operation
# https://en.wikipedia.org/wiki/Associative_property
# https://en.wikipedia.org/wiki/Inverse_element
# https://en.wikipedia.org/wiki/Addition
# https://en.wikipedia.org/wiki/Generating_set
# https://en.wikipedia.org/wiki/0.999...
# https://en.wikipedia.org/wiki/Decimal_point
# https://en.wikipedia.org/wiki/Numeral_system
# https://en.wikipedia.org/wiki/Supremum
# Equation '{\\displaystyle A\\neq \\varnothing }' failed to render
# Equation '{\\displaystyle -\\infty =\\sup \\varnothing <\\inf \\varnothing =\\infty .}' failed to render
# Equation '{\\displaystyle A=\\varnothing \\neq B}' failed to render
# Equation '{\\displaystyle S\\neq \\varnothing }' failed to render
# Equation '{\\displaystyle \\Omega \\neq \\varnothing }' failed to render
# https://en.wikipedia.org/wiki/Intuitive
# https://en.wikipedia.org/wiki/Mathematical_rigor
# https://en.wikipedia.org/wiki/Hypotrochoid
# https://en.wikipedia.org/wiki/Ellipse
# Equation '{\\displaystyle {\\begin{aligned}a,b&={\\frac {-{\\sqrt {2{\\big (}AE^{2}+CD^{2}-BDE+(B^{2}-4AC)F{\\big )}{\\big (}(A+C)\\pm {\\sqrt {(A-C)^{2}+B^{2}}}{\\big )}}}}{B^{2}-4AC}},\\\\x_{\\circ }&={\\frac {2CD-BE}{B^{2}-4AC}},\\\\u]y_{\\circ }&={\\frac {2AE-BD}{B^{2}-4AC}},\\\\u]\\theta &={\\tfrac {1}{2}}\\operatorname {atan2} (-B,\\,C-A),\\end{aligned}}}' failed to render
# Equation '{\\displaystyle {\\begin{cases}x(u)=a\\,{\\dfrac {1-u^{2}}{1+u^{2}}}\\\\u]y(u)=b\\,{\\dfrac {2u}{1+u^{2}}}\\\\u]-\\infty <u<\\infty \\end{cases}}}' failed to render
# Equation '{\\displaystyle (x_{2},y_{2})=({\\color {red}{\\mp }}a\\sin t,\\pm b\\cos t)\\quad }' failed to render
# Equation '{\\displaystyle {\\frac {({\\color {red}x}-x_{1})({\\color {red}x}-x_{2})+({\\color {red}y}-y_{1})({\\color {red}y}-y_{2})}{({\\color {red}y}-y_{1})({\\color {red}x}-x_{2})-({\\color {red}y}-y_{2})({\\color {red}x}-x_{1})}}={\\frac {(x_{3}-x_{1})(x_{3}-x_{2})+(y_{3}-y_{1})(y_{3}-y_{2})}{(y_{3}-y_{1})(x_{3}-x_{2})-(y_{3}-y_{2})(x_{3}-x_{1})}}.}' failed to render
# Equation '{\\displaystyle {\\frac {\\left({\\color {red}{\\vec {x}}}-{\\vec {x}}_{1}\\right)\\cdot \\left({\\color {red}{\\vec {x}}}-{\\vec {x}}_{2}\\right)}{\\det \\left({\\color {red}{\\vec {x}}}-{\\vec {x}}_{1},{\\color {red}{\\vec {x}}}-{\\vec {x}}_{2}\\right)}}={\\frac {\\left({\\vec {x}}_{3}-{\\vec {x}}_{1}\\right)\\cdot \\left({\\vec {x}}_{3}-{\\vec {x}}_{2}\\right)}{\\det \\left({\\vec {x}}_{3}-{\\vec {x}}_{1},{\\vec {x}}_{3}-{\\vec {x}}_{2}\\right)}}.}' failed to render
# Equation '{\\displaystyle {\\color {blue}q}={\\frac {a^{2}}{b^{2}}}={\\frac {1}{1-e^{2}}},}' failed to render
# Equation '{\\displaystyle \\left(x-x_{\\circ }\\right)^{2}+{\\color {blue}q}\\,\\left(y-y_{\\circ }\\right)^{2}=a^{2},}' failed to render
# Equation '{\\displaystyle {\\frac {1+{\\color {blue}q}\\;m_{1}m_{2}}{m_{2}-m_{1}}}\\ .}' failed to render
# Equation '{\\displaystyle (x-x_{\\circ })^{2}+{\\color {blue}q}\\,(y-y_{\\circ })^{2}=a^{2}}' failed to render
# Equation '{\\displaystyle {\\frac {(x_{4}-x_{1})(x_{4}-x_{2})+{\\color {blue}q}\\;(y_{4}-y_{1})(y_{4}-y_{2})}{(y_{4}-y_{1})(x_{4}-x_{2})-(y_{4}-y_{2})(x_{4}-x_{1})}}={\\frac {(x_{3}-x_{1})(x_{3}-x_{2})+{\\color {blue}q}\\;(y_{3}-y_{1})(y_{3}-y_{2})}{(y_{3}-y_{1})(x_{3}-x_{2})-(y_{3}-y_{2})(x_{3}-x_{1})}}\\ .}' failed to render
# Equation '{\\displaystyle {\\frac {({\\color {red}x}-x_{1})({\\color {red}x}-x_{2})+{\\color {blue}q}\\;({\\color {red}y}-y_{1})({\\color {red}y}-y_{2})}{({\\color {red}y}-y_{1})({\\color {red}x}-x_{2})-({\\color {red}y}-y_{2})({\\color {red}x}-x_{1})}}={\\frac {(x_{3}-x_{1})(x_{3}-x_{2})+{\\color {blue}q}\\;(y_{3}-y_{1})(y_{3}-y_{2})}{(y_{3}-y_{1})(x_{3}-x_{2})-(y_{3}-y_{2})(x_{3}-x_{1})}}\\ .}' failed to render
# Equation '{\\displaystyle {\\frac {\\left({\\color {red}{\\vec {x}}}-{\\vec {x}}_{1}\\right)*\\left({\\color {red}{\\vec {x}}}-{\\vec {x}}_{2}\\right)}{\\det \\left({\\color {red}{\\vec {x}}}-{\\vec {x}}_{1},{\\color {red}{\\vec {x}}}-{\\vec {x}}_{2}\\right)}}={\\frac {\\left({\\vec {x}}_{3}-{\\vec {x}}_{1}\\right)*\\left({\\vec {x}}_{3}-{\\vec {x}}_{2}\\right)}{\\det \\left({\\vec {x}}_{3}-{\\vec {x}}_{1},{\\vec {x}}_{3}-{\\vec {x}}_{2}\\right)}},}' failed to render
# Equation '{\\displaystyle {\\vec {u}}*{\\vec {v}}=u_{x}v_{x}+{\\color {blue}q}\\,u_{y}v_{y}.}' failed to render
# https://en.wikipedia.org/wiki/Hypocycloid
# https://en.wikipedia.org/wiki/Lie_group
# https://en.wikipedia.org/wiki/Epitrochoid
# https://en.wikipedia.org/wiki/Spirograph
# https://en.wikipedia.org/wiki/Epicyclic_gearing
# https://en.wikipedia.org/wiki/World_War_II
# https://en.wikipedia.org/wiki/Radar
# https://en.wikipedia.org/wiki/3D_printing
# https://en.wikipedia.org/wiki/Combinatorics
# https://en.wikipedia.org/wiki/Group_testing
# Equation '{\\displaystyle \\mathbb {P} ({\\textrm {success}})\\leq {\\frac {2^{t}}{n \\choose d}}}' failed to render
# https://en.wikipedia.org/wiki/Robert_Dorfman
# https://en.wikipedia.org/wiki/International_Mathematical_Olympiad
# https://en.wikipedia.org/wiki/Mathematical_olympiad
# https://en.wikipedia.org/wiki/Student_competition
# https://en.wikipedia.org/wiki/International_Science_Olympiad
# https://en.wikipedia.org/wiki/Romania
# https://en.wikipedia.org/wiki/Algebra
# https://en.wikipedia.org/wiki/Projective_geometry
# Equation '{\\displaystyle x\\ {\\overset {A}{\\doublebarwedge }}\\ p\\ {\\overset {B}{\\doublebarwedge }}\\ X.}' failed to render
# Equation '{\\displaystyle x\\ \\barwedge \\ X.}' failed to render
# Equation '{\\displaystyle \\barwedge }' failed to render
# Equation '{\\displaystyle C(\\barwedge )\\ =\\ \\bigcup \\{xX\\cdot yY:x\\barwedge X\\ \\ \\land \\ \\ y\\barwedge Y\\}.}' failed to render
# https://en.wikipedia.org/wiki/Complex_geometry
# https://en.wikipedia.org/wiki/Functional_equations
# https://en.wikipedia.org/wiki/Number_theory
# https://en.wikipedia.org/wiki/17-animal_inheritance_puzzle
# https://en.wikipedia.org/wiki/Mathematical_puzzle
# https://en.wikipedia.org/wiki/Fair_item_allocation
# https://en.wikipedia.org/wiki/Utility_functions_on_indivisible_goods
# Equation '{\\displaystyle UD\\subsetneq GS\\subsetneq Submodular\\subsetneq Subadditive}' failed to render
# https://en.wikipedia.org/wiki/Anecdote
# https://en.wikipedia.org/wiki/Parable
# https://en.wikipedia.org/wiki/30_St_Mary_Axe
# https://en.wikipedia.org/wiki/Parametric_design
# https://en.wikipedia.org/wiki/Solid_of_revolution
# https://en.wikipedia.org/wiki/Mathematics_and_architecture
# https://en.wikipedia.org/wiki/Mathematics_and_art
# https://en.wikipedia.org/wiki/Architect
# https://en.wikipedia.org/wiki/Building
# https://en.wikipedia.org/wiki/Geometry
# https://en.wikipedia.org/wiki/Pythagoreanism
# https://en.wikipedia.org/wiki/Aesthetic
# https://en.wikipedia.org/wiki/Tessellation
# https://en.wikipedia.org/wiki/Ancient_Egyptian_architecture
# https://en.wikipedia.org/wiki/Ancient_Greek_architecture
# https://en.wikipedia.org/wiki/Architecture_of_India
# https://en.wikipedia.org/wiki/Islamic_architecture
# https://en.wikipedia.org/wiki/Egyptian_pyramids
# https://en.wikipedia.org/wiki/Mausoleum
# https://en.wikipedia.org/wiki/Islamic_geometric_patterns
# https://en.wikipedia.org/wiki/Fractal
# https://en.wikipedia.org/wiki/Hindu_cosmology
# https://en.wikipedia.org/wiki/Chinese_architecture
# https://en.wikipedia.org/wiki/Tulou
# https://en.wikipedia.org/wiki/Fujian_province
# https://en.wikipedia.org/wiki/Caspar_Netscher
# https://en.wikipedia.org/wiki/Museum_Boerhaave
# https://en.wikipedia.org/wiki/Leiden
# https://en.wikipedia.org/wiki/Christiaan_Huygens
# https://en.wikipedia.org/wiki/Halen
# https://en.wikipedia.org/wiki/Fellow_of_the_Royal_Society
# https://en.wikipedia.org/wiki/Latin_language
# https://en.wikipedia.org/wiki/Engineer
# https://en.wikipedia.org/wiki/Inventor
# https://en.wikipedia.org/wiki/Scientific_revolution
# https://en.wikipedia.org/wiki/Rings_of_Saturn
# https://en.wikipedia.org/wiki/Titan_(moon)
# https://en.wikipedia.org/wiki/Pendulum_clock
# https://en.wikipedia.org/wiki/Mathematical_model
# https://en.wikipedia.org/wiki/Parameter
# https://en.wikipedia.org/wiki/Unobservable
# https://en.wikipedia.org/wiki/Elastic_collision
# https://en.wikipedia.org/wiki/Centrifugal_force
# https://en.wikipedia.org/wiki/Isaac_Newton
# https://en.wikipedia.org/wiki/Wave_theory_of_light
# https://en.wikipedia.org/wiki/Treatise_on_Light
# https://en.wikipedia.org/wiki/Opticks
# https://en.wikipedia.org/wiki/Augustin-Jean_Fresnel
# https://en.wikipedia.org/wiki/Huygens%E2%80%93Fresnel_principle
# https://en.wikipedia.org/wiki/Apple
# https://en.wikipedia.org/wiki/Plus_and_minus_signs#Plus_sign
# https://en.wikipedia.org/wiki/Operation_(mathematics)
# https://en.wikipedia.org/wiki/Arithmetic
# Equation '{\\displaystyle \\varnothing }' failed to render
# https://en.wikipedia.org/wiki/Subtraction
# Equation '{\\displaystyle {\\begin{array}{rrrr}&\\color {Red}-1\\\\&C&D&U\\\\&7&0&4\\\\&5&1&2\\\\\\hline &1&9&2\\\\\\end{array}}{\\begin{array}{l}{\\color {Red}\\longleftarrow {\\rm {carry}}}\\\\\\\\\\longleftarrow \\;{\\rm {Minuend}}\\\\\\longleftarrow \\;{\\rm {Subtrahend}}\\\\\\longleftarrow {\\rm {Rest\\;or\\;Difference}}\\\\\\end{array}}}' failed to render
# https://en.wikipedia.org/wiki/Multiplication
# https://en.wikipedia.org/wiki/Division_(mathematics)
# https://en.wikipedia.org/wiki/Expression_(mathematics)
# https://en.wikipedia.org/wiki/Equality_(mathematics)
# https://en.wikipedia.org/wiki/Counting
# https://en.wikipedia.org/wiki/Concrete_object
# https://en.wikipedia.org/wiki/Complex_number
# https://en.wikipedia.org/wiki/Euclidean_vector
# https://en.wikipedia.org/wiki/Matrix_(mathematics)
# Equation '{\\displaystyle \\mathbf {A} ={\\begin{bmatrix}4&-7&\\color {red}{5}&0\\\\-2&0&11&8\\\\19&1&-3&12\\end{bmatrix}}}' failed to render
# Equation '{\\displaystyle \\mathbf {A} ={\\begin{bmatrix}1&\\color {red}{2}&3&4\\\\5&\\color {red}{6}&7&8\\\\\\color {red}{9}&\\color {red}{10}&\\color {red}{11}&\\color {red}{12}\\end{bmatrix}}\\rightarrow {\\begin{bmatrix}1&3&4\\\\5&7&8\\end{bmatrix}}.}' failed to render
# https://en.wikipedia.org/wiki/Linear_subspace
# https://en.wikipedia.org/wiki/Subgroup
# https://en.wikipedia.org/wiki/Erd%C5%91s%E2%80%93Straus_conjecture
# https://en.wikipedia.org/wiki/Open_problem
# https://en.wikipedia.org/wiki/Unit_fraction
# https://en.wikipedia.org/wiki/Paul_Erd%C5%91s
# https://en.wikipedia.org/wiki/Ernst_G._Straus
# https://en.wikipedia.org/wiki/Egyptian_fraction
# https://en.wikipedia.org/wiki/Ancient_Egyptian_mathematics
# https://en.wikipedia.org/wiki/Erd%C5%91s_conjecture
# https://en.wikipedia.org/wiki/Diophantine_equation
# https://en.wikipedia.org/wiki/Orthographic_projection
# https://en.wikipedia.org/wiki/Final_stellation_of_the_icosahedron
# https://en.wikipedia.org/wiki/Stellation
# https://en.wikipedia.org/wiki/Icosahedron
# https://en.wikipedia.org/wiki/Stellation_diagram
# https://en.wikipedia.org/wiki/Max_Br%C3%BCckner
# https://en.wikipedia.org/wiki/Kepler%E2%80%93Poinsot_polyhedron
# https://en.wikipedia.org/wiki/Simple_polyhedron
# https://en.wikipedia.org/wiki/Star_polyhedron
# https://en.wikipedia.org/wiki/Free_abelian_group
# https://en.wikipedia.org/wiki/Abelian_group
# https://en.wikipedia.org/wiki/Free_module
# https://en.wikipedia.org/wiki/Associative
# https://en.wikipedia.org/wiki/Commutative
# https://en.wikipedia.org/wiki/Subset
# Equation '{\\displaystyle A\\subsetneq B}' failed to render
# Equation '{\\displaystyle B\\supsetneq A}' failed to render
# Equation '{\\displaystyle \\varnothing ,}' failed to render
# Equation '{\\displaystyle \\subsetneq }' failed to render
# Equation '{\\displaystyle \\supsetneq .}' failed to render
# Equation '{\\displaystyle A\\subsetneq B}' failed to render
# Equation '{\\displaystyle D\\subsetneq E}' failed to render
# Equation '{\\displaystyle X\\subsetneq X}' failed to render
# https://en.wikipedia.org/wiki/Linear_combination
# https://en.wikipedia.org/wiki/Integer_lattice
# Equation '{\\displaystyle (\\mathbb {Z} _{2})^{n}\\rtimes S_{n}}' failed to render
# https://en.wikipedia.org/wiki/Vector_space
# https://en.wikipedia.org/wiki/Lattice_(group)
# https://en.wikipedia.org/wiki/Algebraic_topology
# https://en.wikipedia.org/wiki/Chain_(algebraic_topology)
# https://en.wikipedia.org/wiki/Algebraic_geometry
# https://en.wikipedia.org/wiki/Divisor_(algebraic_geometry)
# https://en.wikipedia.org/wiki/Multiset
# Equation '{\\displaystyle {\\begin{aligned}\\left(\\!\\!{4 \\choose 18}\\!\\!\\right)&={21 \\choose 18}={\\frac {21!}{18!\\,3!}}={21 \\choose 3},\\\\[1ex]&={\\frac {{\\color {red}{\\mathfrak {4\\cdot 5\\cdot 6\\cdot 7\\cdot 8\\cdot 9\\cdot 10\\cdot 11\\cdot 12\\cdot 13\\cdot 14\\cdot 15\\cdot 16\\cdot 17\\cdot 18}}}\\cdot \\mathbf {19\\cdot 20\\cdot 21} }{\\mathbf {1\\cdot 2\\cdot 3} \\cdot {\\color {red}{\\mathfrak {4\\cdot 5\\cdot 6\\cdot 7\\cdot 8\\cdot 9\\cdot 10\\cdot 11\\cdot 12\\cdot 13\\cdot 14\\cdot 15\\cdot 16\\cdot 17\\cdot 18}}}}},\\\\[1ex]&={\\frac {1\\cdot 2\\cdot 3\\cdot 4\\cdot 5\\cdots 16\\cdot 17\\cdot 18\\;\\mathbf {\\cdot \\;19\\cdot 20\\cdot 21} }{\\,1\\cdot 2\\cdot 3\\cdot 4\\cdot 5\\cdots 16\\cdot 17\\cdot 18\\;\\mathbf {\\cdot \\;1\\cdot 2\\cdot 3\\quad } }},\\\\[1ex]&={\\frac {19\\cdot 20\\cdot 21}{1\\cdot 2\\cdot 3}}.\\end{aligned}}}' failed to render
# https://en.wikipedia.org/wiki/Function_(mathematics)
# Equation '{\\displaystyle \\varnothing \\to X}' failed to render
# Equation '{\\displaystyle \\varnothing \\to Y}' failed to render
# https://en.wikipedia.org/wiki/Pointwise
# https://en.wikipedia.org/wiki/Ronald_Graham
# https://en.wikipedia.org/wiki/American_Mathematical_Society
# https://en.wikipedia.org/wiki/Discrete_mathematics
# https://en.wikipedia.org/wiki/Mathematical_Association_of_America
# https://en.wikipedia.org/wiki/Leroy_P._Steele_Prize
# https://en.wikipedia.org/wiki/National_Academy_of_Sciences
# https://en.wikipedia.org/wiki/University_of_California,_Berkeley
# https://en.wikipedia.org/wiki/Bell_Labs
# https://en.wikipedia.org/wiki/University_of_California,_San_Diego
# https://en.wikipedia.org/wiki/Scheduling_algorithm
# https://en.wikipedia.org/wiki/Ramsey_theory
# https://en.wikipedia.org/wiki/Quasi-randomness
# https://en.wikipedia.org/wiki/Fan_Chung
# https://en.wikipedia.org/wiki/Fibonacci_nim
# https://en.wikipedia.org/wiki/Subtraction_game
# https://en.wikipedia.org/wiki/Nim
# https://en.wikipedia.org/wiki/Fibonacci_number
# Equation '{\\displaystyle {\\begin{aligned}\\varphi ^{n}&=\\varphi ^{n-1}+\\varphi ^{n-2},\\\\u]\\psi ^{n}&=\\psi ^{n-1}+\\psi ^{n-2}.\\end{aligned}}}' failed to render
# Equation '{\\displaystyle {\\begin{aligned}U_{n}&=a\\varphi ^{n}+b\\psi ^{n}\\\\u]&=a(\\varphi ^{n-1}+\\varphi ^{n-2})+b(\\psi ^{n-1}+\\psi ^{n-2})\\\\u]&=a\\varphi ^{n-1}+b\\psi ^{n-1}+a\\varphi ^{n-2}+b\\psi ^{n-2}\\\\u]&=U_{n-1}+U_{n-2}.\\end{aligned}}}' failed to render
# Equation '{\\displaystyle {\\begin{aligned}a&={\\frac {U_{1}-U_{0}\\psi }{\\sqrt {5}}},\\\\u]b&={\\frac {U_{0}\\varphi -U_{1}}{\\sqrt {5}}}.\\end{aligned}}}' failed to render
# Equation '{\\displaystyle {\\begin{aligned}A&=S\\Lambda S^{-1},\\\\u]A^{n}&=S\\Lambda ^{n}S^{-1},\\end{aligned}}}' failed to render
# Equation '{\\displaystyle {\\begin{aligned}{F_{m}}{F_{n}}+{F_{m-1}}{F_{n-1}}&=F_{m+n-1},\\\\u]F_{m}F_{n+1}+F_{m-1}F_{n}&=F_{m+n}.\\end{aligned}}}' failed to render
# Equation '{\\displaystyle {\\begin{aligned}F_{2n-1}&={F_{n}}^{2}+{F_{n-1}}^{2}\\\\u]F_{2n{\\phantom {{}-1}}}&=(F_{n-1}+F_{n+1})F_{n}\\\\u]&=(2F_{n-1}+F_{n})F_{n}\\\\u]&=(2F_{n+1}-F_{n})F_{n}.\\end{aligned}}}' failed to render
# https://en.wikipedia.org/wiki/Namib_Desert
# https://en.wikipedia.org/wiki/Barchan
# https://en.wikipedia.org/wiki/Capillary_wave
# https://en.wikipedia.org/wiki/Patterns_in_nature
# https://en.wikipedia.org/wiki/Nature
# https://en.wikipedia.org/wiki/Patterns
# https://en.wikipedia.org/wiki/Modelled_mathematically
# https://en.wikipedia.org/wiki/Symmetries
# https://en.wikipedia.org/wiki/Trees
# https://en.wikipedia.org/wiki/Spirals
# Equation '{\\displaystyle x=r(\\varphi )\\cos \\varphi \\ ,\\qquad y=r(\\varphi )\\sin \\varphi \\ ,\\qquad \\color {red}{z=z_{0}+mr(\\varphi )}\\ .}' failed to render
# Equation '{\\displaystyle {\\begin{array}{cll}x&=&r\\cdot \\sin \\theta \\cdot \\cos {\\color {red}c\\theta }\\\\y&=&r\\cdot \\sin \\theta \\cdot \\sin {\\color {red}c\\theta }\\\\z&=&r\\cdot \\cos \\theta \\qquad \\qquad 0\\leq \\theta \\leq \\pi \\ .\\end{array}}}' failed to render
# https://en.wikipedia.org/wiki/Meanders
# https://en.wikipedia.org/wiki/Wave
# https://en.wikipedia.org/wiki/Foams
# https://en.wikipedia.org/wiki/Tessellations
# https://en.wikipedia.org/wiki/Fracture
# https://en.wikipedia.org/wiki/Greek_philosophers
# https://en.wikipedia.org/wiki/Plato
# https://en.wikipedia.org/wiki/Pythagoras
# https://en.wikipedia.org/wiki/Empedocles
# https://en.wikipedia.org/wiki/Joseph_Plateau
# https://en.wikipedia.org/wiki/Soap_film
# https://en.wikipedia.org/wiki/Minimal_surface
# https://en.wikipedia.org/wiki/Ernst_Haeckel
# https://en.wikipedia.org/wiki/Marine_biology
# https://en.wikipedia.org/wiki/Symmetry
# https://en.wikipedia.org/wiki/D%27Arcy_Thompson
# https://en.wikipedia.org/wiki/Alan_Turing
# https://en.wikipedia.org/wiki/Morphogenesis
# https://en.wikipedia.org/wiki/Turing_patterns
# https://en.wikipedia.org/wiki/Aristid_Lindenmayer
# https://en.wikipedia.org/wiki/Beno%C3%AEt_Mandelbrot
# https://en.wikipedia.org/wiki/Fractals
# https://en.wikipedia.org/wiki/Math_rock
# https://en.wikipedia.org/wiki/Cryptooology
# https://en.wikipedia.org/wiki/Yowie_(band)
# https://en.wikipedia.org/wiki/Slinky
# https://en.wikipedia.org/wiki/List_of_mathematics_competitions
# https://en.wikipedia.org/wiki/Sophie_Germain%27s_identity
# https://en.wikipedia.org/wiki/Subgroup_distortion
# https://en.wikipedia.org/wiki/Mikhael_Gromov_(mathematician)
# https://en.wikipedia.org/wiki/Doyle_spiral
# https://en.wikipedia.org/wiki/Posthumous_publication
# https://en.wikipedia.org/wiki/Donn_Piatt
# https://en.wikipedia.org/wiki/Straightedge_and_compass_construction
# Equation '{\\displaystyle {\\begin{aligned}\\cos {\\left({\\frac {2\\pi }{17}}\\right)}&=\\,-{\\frac {1}{16}}\\,+\\,{\\frac {1}{16}}{\\sqrt {17}}\\,+\\,{\\frac {1}{16}}{\\sqrt {34-2{\\sqrt {17}}}}\\\\u]&\\qquad +\\,{\\frac {1}{8}}{\\sqrt {17+3{\\sqrt {17}}-{\\sqrt {34-2{\\sqrt {17}}}}-2{\\sqrt {34+2{\\sqrt {17}}}}}}\\end{aligned}}}' failed to render
# https://en.wikipedia.org/wiki/Daniel_Larsen_(mathematician)
# https://en.wikipedia.org/wiki/The_New_York_Times_crossword_puzzle
# https://en.wikipedia.org/wiki/Clique_problem
# https://en.wikipedia.org/wiki/Complete_graph
# https://en.wikipedia.org/wiki/Glossary_of_graph_theory#Subgraphs
# https://en.wikipedia.org/wiki/Undirected_graph
# https://en.wikipedia.org/wiki/Social_network
# https://en.wikipedia.org/wiki/Herschel_graph
# https://en.wikipedia.org/wiki/Polyhedral_graph
# https://en.wikipedia.org/wiki/Hamiltonian_cycle
# https://en.wikipedia.org/wiki/Life_without_Death
# https://en.wikipedia.org/wiki/Cellular_automaton
# https://en.wikipedia.org/wiki/Pattern_formation
# https://en.wikipedia.org/wiki/Conway%27s_Game_of_Life
# https://en.wikipedia.org/wiki/Positive_number
# https://en.wikipedia.org/wiki/Rational_number
# https://en.wikipedia.org/wiki/Breadth-first_search
# https://en.wikipedia.org/wiki/Calkin%E2%80%93Wilf_tree
# https://en.wikipedia.org/wiki/Hadwiger_conjecture_(combinatorial_geometry)
# https://en.wikipedia.org/wiki/Solid_geometry
# https://en.wikipedia.org/wiki/Convex_body
# https://en.wikipedia.org/wiki/Lighting
# https://en.wikipedia.org/wiki/Equitable_coloring
# https://en.wikipedia.org/wiki/Graph_coloring
# https://en.wikipedia.org/wiki/Fair_coin
# Equation '{\\displaystyle \\therefore E(F)=2+E(F)-2P(H)P(T)E(F)\\Rightarrow E(F)={\\frac {1}{P(H)P(T)}}={\\frac {1}{P(H)(1-P(H))}}}' failed to render
# https://en.wikipedia.org/wiki/Coin_flipping
# https://en.wikipedia.org/wiki/Edge_(graph_theory)
# https://en.wikipedia.org/wiki/Countability
# https://en.wikipedia.org/wiki/Graph_isomorphism
# https://en.wikipedia.org/wiki/Rado_graph
# https://en.wikipedia.org/wiki/Order_of_the_British_Empire
# https://en.wikipedia.org/wiki/England
# https://en.wikipedia.org/wiki/Cryptographer
# https://en.wikipedia.org/wiki/Algorithm
# https://en.wikipedia.org/wiki/Turing_machine
# https://en.wikipedia.org/wiki/Church%E2%80%93Turing_thesis
# https://en.wikipedia.org/wiki/Turing_test
# https://en.wikipedia.org/wiki/Artificial_intelligence
# https://en.wikipedia.org/wiki/Consciousness
# https://en.wikipedia.org/wiki/Thought
# https://en.wikipedia.org/wiki/National_Physical_Laboratory,_UK
# https://en.wikipedia.org/wiki/Victoria_University_of_Manchester
# https://en.wikipedia.org/wiki/Manchester_Mark_I
# https://en.wikipedia.org/wiki/Bletchley_Park
# https://en.wikipedia.org/wiki/Cryptanalysis
# https://en.wikipedia.org/wiki/Hut_8
# https://en.wikipedia.org/wiki/Bombe
# https://en.wikipedia.org/wiki/Areas_of_mathematics
# https://en.wikipedia.org/wiki/History_of_mathematics
# https://en.wikipedia.org/wiki/Philosophy_of_mathematics
# https://en.wikipedia.org/wiki/Mathematical_beauty
# https://en.wikipedia.org/wiki/Mathematics_education
# https://en.wikipedia.org/wiki/Outline_of_mathematics
# https://en.wikipedia.org/wiki/Glossary_of_mathematical_symbols
# Equation '{\\displaystyle \\triangleq \\quad {\\stackrel {\\scriptscriptstyle \\mathrm {def} }{=}}\\quad :=}' failed to render
# Equation '{\\displaystyle x\\triangleq E,}' failed to render
# Equation '{\\displaystyle \\leqq }' failed to render
# Equation '{\\displaystyle A\\subsetneq B}' failed to render
# Equation '{\\displaystyle \\subsetneq }' failed to render
# Equation '{\\displaystyle \\complement }' failed to render
# Equation '{\\displaystyle \\complement _{A}B=A\\setminus B}' failed to render
# Equation '{\\displaystyle \\complement A=\\complement _{U}A}' failed to render
# Equation '{\\displaystyle E\\veebar F}' failed to render
# Equation '{\\displaystyle E\\veebar F}' failed to render
# Equation '{\\displaystyle G=N\\rtimes H}' failed to render
# Equation '{\\displaystyle G=H\\ltimes N}' failed to render
# Equation '{\\displaystyle N\\rtimes _{\\varphi }H=H\\ltimes _{\\varphi }N}' failed to render
# Equation '{\\displaystyle \\beth }' failed to render
# Equation '{\\displaystyle \\beth _{0}}' failed to render
# Equation '{\\displaystyle \\beth _{1}}' failed to render
# Equation '{\\displaystyle n\\nmid m}' failed to render
# https://en.wikipedia.org/wiki/Mathematical_logic
# Equation '{\\displaystyle A\\leftrightharpoons B}' failed to render
# Equation '{\\displaystyle A\\nleftrightarrow B}' failed to render
# https://en.wikipedia.org/wiki/Proof_theory
# https://en.wikipedia.org/wiki/G%C3%B6del%27s_incompleteness_theorems
# https://en.wikipedia.org/wiki/Model_theory
# https://en.wikipedia.org/wiki/Recursion_theory
# https://en.wikipedia.org/wiki/Naive_set_theory
# Equation '{\\displaystyle \\varnothing }' failed to render
# Equation '{\\displaystyle \\varnothing \\neq \\{\\varnothing \\}}' failed to render
# https://en.wikipedia.org/wiki/Axiomatic_set_theory
# https://en.wikipedia.org/wiki/Category_theory
# https://en.wikipedia.org/wiki/Topos_theory
# https://en.wikipedia.org/wiki/Algebraic_number_theory
# Equation '{\\displaystyle v\\nmid \\infty }' failed to render
# https://en.wikipedia.org/wiki/Fundamental_theorem_of_arithmetic
# https://en.wikipedia.org/wiki/Prime_number
# https://en.wikipedia.org/wiki/Algebraic_number
# https://en.wikipedia.org/wiki/Combinatorial_geometry
# https://en.wikipedia.org/wiki/Coding_theory
# https://en.wikipedia.org/wiki/Combinatorial_design
# https://en.wikipedia.org/wiki/Enumerative_combinatorics
# https://en.wikipedia.org/wiki/Combinatorial_optimization
# https://en.wikipedia.org/wiki/Order_theory
# https://en.wikipedia.org/wiki/Lattice_theory
# Equation '{\\displaystyle S\\neq \\varnothing :}' failed to render
# Equation '{\\displaystyle {\\text{ for all }}a\\in \\varnothing ,x\\leq a}' failed to render
# Equation '{\\displaystyle {\\text{ for all }}a\\in \\varnothing ,a\\leq x,}' failed to render
# Equation '{\\displaystyle \\bigvee (A\\cup \\varnothing )=\\left(\\bigvee A\\right)\\vee \\left(\\bigvee \\varnothing \\right)=\\left(\\bigvee A\\right)\\vee 0=\\bigvee A}' failed to render
# Equation '{\\displaystyle \\bigwedge (A\\cup \\varnothing )=\\left(\\bigwedge A\\right)\\wedge \\left(\\bigwedge \\varnothing \\right)=\\left(\\bigwedge A\\right)\\wedge 1=\\bigwedge A,}' failed to render
# Equation '{\\displaystyle A\\cup \\varnothing =A.}' failed to render
# https://en.wikipedia.org/wiki/Digital_Signal_Processing
# https://en.wikipedia.org/wiki/Theoretical_computer_science
# https://en.wikipedia.org/wiki/Computability_theory_(computation)
# https://en.wikipedia.org/wiki/Computational_complexity_theory
# Equation '{\\displaystyle {\\mathsf {DTIME}}{\\big (}o(f(n)){\\big )}\\subsetneq {\\mathsf {DTIME}}{\\big (}f(n)\\cdot \\log(f(n)){\\big )}}' failed to render
# Equation '{\\displaystyle {\\mathsf {DSPACE}}{\\big (}o(f(n)){\\big )}\\subsetneq {\\mathsf {DSPACE}}{\\big (}f(n){\\big )}}' failed to render
# https://en.wikipedia.org/wiki/Elementary_algebra
# https://en.wikipedia.org/wiki/Group_theory
# https://en.wikipedia.org/wiki/Ring_theory
# Equation '{\\displaystyle {\\mathfrak {p}}_{0}\\subsetneq {\\mathfrak {p}}_{1}\\subsetneq \\cdots \\subsetneq {\\mathfrak {p}}_{n}}' failed to render
# Equation "{\\displaystyle {\\mathfrak {p}}={\\mathfrak {p}}_{0}\\subsetneq \\cdots \\subsetneq {\\mathfrak {p}}_{n}={\\mathfrak {p}}'}" failed to render
# https://en.wikipedia.org/wiki/Field_theory_(mathematics)
# Equation '{\\displaystyle (F\\smallsetminus \\{0\\},\\cdot )}' failed to render
# Equation '{\\displaystyle F\\smallsetminus \\{0\\}}' failed to render
# Equation '{\\displaystyle F\\smallsetminus \\{0\\}}' failed to render
# Equation '{\\displaystyle K_{n}^{M}(F)=F^{\\times }\\otimes \\cdots \\otimes F^{\\times }/\\left\\langle x\\otimes (1-x)\\mid x\\in F\\smallsetminus \\{0,1\\}\\right\\rangle .}' failed to render
# Equation '{\\displaystyle \\left\\langle F\\smallsetminus \\{0\\},\\cdot ,{}^{-1}\\right\\rangle }' failed to render
# https://en.wikipedia.org/wiki/Commutative_algebra
# https://en.wikipedia.org/wiki/Geometric_algebra
# https://en.wikipedia.org/wiki/Linear_algebra
# https://en.wikipedia.org/wiki/Multilinear_algebra
# https://en.wikipedia.org/wiki/Universal_algebra
# https://en.wikipedia.org/wiki/Fundamental_theorem_of_algebra
# https://en.wikipedia.org/wiki/Mathematical_analysis
# https://en.wikipedia.org/wiki/Fundamental_theorem_of_calculus
# https://en.wikipedia.org/wiki/Geometric_calculus
# https://en.wikipedia.org/wiki/Measure_theory
# Equation '{\\displaystyle \\mu (\\varnothing )=0.}' failed to render
# Equation '{\\displaystyle \\mu (\\varnothing )=0}' failed to render
# Equation '{\\displaystyle \\mu (E)=\\mu (E\\cup \\varnothing )=\\mu (E)+\\mu (\\varnothing ),}' failed to render
# Equation '{\\displaystyle \\mu (\\varnothing )=0.}' failed to render
# https://en.wikipedia.org/wiki/Real_analysis
# Equation '{\\displaystyle f_{n}\\rightrightarrows f}' failed to render
# https://en.wikipedia.org/wiki/Differential_equations
# https://en.wikipedia.org/wiki/Ordinary_differential_equation
# https://en.wikipedia.org/wiki/Partial_differential_equation
# https://en.wikipedia.org/wiki/Integral_equation
# https://en.wikipedia.org/wiki/Approximation_theory
# https://en.wikipedia.org/wiki/Special_functions
# https://en.wikipedia.org/wiki/Potential_theory
# https://en.wikipedia.org/wiki/Harmonic_analysis
# https://en.wikipedia.org/wiki/Fourier_analysis
# Equation '{\\displaystyle s_{P}(t)\\,\\triangleq \\,\\sum _{m=-\\infty }^{\\infty }s(t-mP),}' failed to render
# Equation '{\\displaystyle S_{\\frac {1}{T}}(f)\\ \\triangleq \\ \\underbrace {\\sum _{k=-\\infty }^{\\infty }S\\left(f-{\\frac {k}{T}}\\right)\\equiv \\overbrace {\\sum _{n=-\\infty }^{\\infty }s[n]\\cdot e^{-i2\\pi fnT}} ^{\\text{Fourier series (DTFT)}}} _{\\text{Poisson summation formula}}={\\mathcal {F}}\\left\\{\\sum _{n=-\\infty }^{\\infty }s[n]\\ \\delta (t-nT)\\right\\},\\,}' failed to render
# Equation '{\\displaystyle s[n]\\ \\triangleq \\ T\\int _{\\frac {1}{T}}S_{\\frac {1}{T}}(f)\\cdot e^{i2\\pi fnT}\\,df=T\\underbrace {\\int _{-\\infty }^{\\infty }S(f)\\cdot e^{i2\\pi fnT}\\,df} _{\\triangleq \\,s(nT)}.}' failed to render
# Equation '{\\displaystyle s_{N}[n]\\,\\triangleq \\,\\sum _{m=-\\infty }^{\\infty }s[n-mN],}' failed to render
# Equation '{\\displaystyle s[n]\\,\\triangleq \\,s(nT),}' failed to render
# Equation '{\\displaystyle S(f)\\,\\triangleq \\,\\int _{-\\infty }^{\\infty }s(t)\\cdot e^{-i2\\pi ft}\\,dt}' failed to render
# Equation '{\\displaystyle \\overbrace {{\\frac {1}{P}}\\cdot S\\left({\\frac {k}{P}}\\right)} ^{S[k]}\\,\\triangleq \\,{\\frac {1}{P}}\\int _{-\\infty }^{\\infty }s(t)\\cdot e^{-i2\\pi {\\frac {k}{P}}t}\\,dt\\equiv {\\frac {1}{P}}\\int _{P}s_{P}(t)\\cdot e^{-i2\\pi {\\frac {k}{P}}t}\\,dt}' failed to render
# Equation '{\\displaystyle \\underbrace {{\\frac {1}{T}}S_{\\frac {1}{T}}(f)\\,\\triangleq \\,\\sum _{n=-\\infty }^{\\infty }s(nT)\\cdot e^{-i2\\pi fnT}} _{\\text{Poisson summation formula (DTFT)}}}' failed to render
# Equation '{\\displaystyle {\\begin{aligned}\\overbrace {{\\frac {1}{T}}S_{\\frac {1}{T}}\\left({\\frac {k}{NT}}\\right)} ^{S[k]}\\,&\\triangleq \\,\\sum _{n=-\\infty }^{\\infty }s(nT)\\cdot e^{-i2\\pi {\\frac {kn}{N}}}\\\\&\\equiv \\underbrace {\\sum _{n}s_{P}(nT)\\cdot e^{-i2\\pi {\\frac {kn}{N}}}} _{\\text{DFT}}\\,\\end{aligned}}}' failed to render
# Equation '{\\displaystyle \\int _{P}\\left(\\sum _{m=-\\infty }^{\\infty }s(t-mP)\\right)\\cdot e^{-i2\\pi {\\frac {k}{P}}t}\\,dt=\\underbrace {\\int _{-\\infty }^{\\infty }s(t)\\cdot e^{-i2\\pi {\\frac {k}{P}}t}\\,dt} _{\\triangleq \\,S\\left({\\frac {k}{P}}\\right)}}' failed to render
# Equation '{\\displaystyle \\sum _{n=0}^{N-1}\\left(\\sum _{m=-\\infty }^{\\infty }s([n-mN]T)\\right)\\cdot e^{-i2\\pi {\\frac {k}{N}}n}=\\underbrace {\\sum _{n=-\\infty }^{\\infty }s(nT)\\cdot e^{-i2\\pi {\\frac {k}{N}}n}} _{\\triangleq \\,{\\frac {1}{T}}S_{\\frac {1}{T}}\\left({\\frac {k}{NT}}\\right)}}' failed to render
# https://en.wikipedia.org/wiki/Functional_analysis
# https://en.wikipedia.org/wiki/Operator_theory
# https://en.wikipedia.org/wiki/Euclidean_geometry
# https://en.wikipedia.org/wiki/Trigonometry
# https://en.wikipedia.org/wiki/Analytic_geometry
# https://en.wikipedia.org/wiki/Non-Euclidean_geometry
# https://en.wikipedia.org/wiki/Affine_geometry
# Equation '{\\displaystyle V\\rtimes \\mathrm {GL} (V).}' failed to render
# https://en.wikipedia.org/wiki/Convex_geometry
# https://en.wikipedia.org/wiki/Discrete_geometry
# https://en.wikipedia.org/wiki/Differential_geometry
# https://en.wikipedia.org/wiki/K_theory
# https://en.wikipedia.org/wiki/Gauge_theory_(mathematics)
# https://en.wikipedia.org/wiki/Riemannian_geometry
# https://en.wikipedia.org/wiki/General_topology
# https://en.wikipedia.org/wiki/Geometric_topology
# https://en.wikipedia.org/wiki/Differential_topology
# https://en.wikipedia.org/wiki/Mathematical_modeling
# https://en.wikipedia.org/wiki/Dynamical_systems
# https://en.wikipedia.org/wiki/Control_theory
# https://en.wikipedia.org/wiki/Calculus_of_variations
# https://en.wikipedia.org/wiki/Mathematical_optimization
# https://en.wikipedia.org/wiki/Mathematical_economics
# https://en.wikipedia.org/wiki/Game_theory
# https://en.wikipedia.org/wiki/Mathematical_finance
# https://en.wikipedia.org/wiki/Probability_theory
# https://en.wikipedia.org/wiki/Stochastic_process
# https://en.wikipedia.org/wiki/Numerical_analysis
# https://en.wikipedia.org/wiki/Information_theory
# Equation '{\\displaystyle I(X^{n}\\to Y^{n})\\triangleq \\sum _{i=1}^{n}I(X^{i};Y_{i}|Y^{i-1})}' failed to render
# https://en.wikipedia.org/wiki/Wikimedia_Foundation
